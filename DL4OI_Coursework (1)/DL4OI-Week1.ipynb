# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
zeroCount=np.count_nonzero(y_train==0)
oneCount=np.count_nonzero(y_train==1)
twoCount=np.count_nonzero(y_train==2)
threeCount=np.count_nonzero(y_train==3)
fourCount=np.count_nonzero(y_train==4)
fiveCount=np.count_nonzero(y_train==5)
sixCount=np.count_nonzero(y_train==6)
sevenCount=np.count_nonzero(y_train==7)
eightCount=np.count_nonzero(y_train==8)
nineCount=np.count_nonzero(y_train==9)

# %%
print(zeroCount, oneCount, twoCount, threeCount, fourCount, fiveCount, sixCount, sevenCount, eightCount, nineCount)
# Out:
# 5923 6742 5958 6131 5842 5421 5918 6265 5851 5949

# %%
zeroPositions=np.where(y_train==0)[0]
onePositions=np.where(y_train==1)[0]
twoPositions=np.where(y_train==2)[0]
threePositions=np.where(y_train==3)[0]
fourPositions=np.where(y_train==4)[0]
fivePositions=np.where(y_train==5)[0]
sixPositions=np.where(y_train==6)[0]
sevenPositions=np.where(y_train==7)[0]
eightPositions=np.where(y_train==8)[0]
ninePositions=np.where(y_train==9)[0]

# %%
print(zeroPositions[3])
plt.imshow(x_train)
# Out:
# 37

# %%
#shows 0s
for i in range(5):
  plt.figure(i)
  plt.imshow(x_train[zeroPositions[i]])

# %%
#shows 1s
for i in range(5):
  plt.figure(i)
  plt.imshow(x_train[onePositions[i]])

# %%
#shows 2s
for i in range(5):
  plt.figure(i)
  plt.imshow(x_train[twoPositions[i]])

# %%
#shows 3s
for i in range(5):
  plt.figure(i)
  plt.imshow(x_train[threePositions[i]])

# %%
#shows 4s
for i in range(5):
  plt.figure(i)
  plt.imshow(x_train[fourPositions[i]])

# %%
#shows 5s
for i in range(5):
  plt.figure(i)
  plt.imshow(x_train[fivePositions[i]])

# %%
#shows 6s
for i in range(5):
  plt.figure(i)
  plt.imshow(x_train[sixPositions[i]])

# %%
#shows 7s
for i in range(5):
  plt.figure(i)
  plt.imshow(x_train[sevenPositions[i]])

# %%
#shows 8s
for i in range(5):
  plt.figure(i)
  plt.imshow(x_train[eightPositions[i]])

# %%
#shows 9s
for i in range(5):
  plt.figure(i)
  plt.imshow(x_train[ninePositions[i]])

# %%
#plot sequence
plt.figure(0)
plt.imshow(x_train[zeroPositions[0]])
plt.figure(1)
plt.imshow(x_train[onePositions[0]])
plt.figure(2)
plt.imshow(x_train[twoPositions[0]])
plt.figure(3)
plt.imshow(x_train[threePositions[0]])
plt.figure(4)
plt.imshow(x_train[fourPositions[0]])
plt.figure(5)
plt.imshow(x_train[fivePositions[0]])
plt.figure(6)
plt.imshow(x_train[sixPositions[0]])
plt.figure(7)
plt.imshow(x_train[sevenPositions[0]])
plt.figure(8)
plt.imshow(x_train[eightPositions[0]])
plt.figure(9)
plt.imshow(x_train[ninePositions[0]])
