# %% [markdown]
# <a href="https://colab.research.google.com/github/Termote/Deep_learning_for_optical_imaging/blob/main/Final_project_DefeatChatGPT_opti_nicolas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Data

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.models import Model
from keras.layers import Input, Activation
from keras.layers import Conv2D, MaxPooling2D,TimeDistributed, Concatenate, Conv3D, MaxPooling3D, BatchNormalization
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import Adam

from sklearn.model_selection import train_test_split

import cv2
import os
import gdown

# %%
# Download the data training folder
url = "https://drive.google.com/drive/folders/15tqljOBNINQ1nh54yFzhZvPcbRJi5RSd"
gdown.download_folder(url, quiet=True, use_cookies=False)
# Out:
# ['/content/Project Files/Data Description.docx',
#  '/content/Project Files/Project presentation.pdf',
#  '/content/Project Files/Sample_Network_GPT.ipynb',
#  '/content/Project Files/Testing Data/common_time_test.npy',
#  '/content/Project Files/Testing Data/ground_truth_test.npy',
#  '/content/Project Files/Testing Data/meteo_data_test.csv',
#  '/content/Project Files/Testing Data/X_test1.npy',
#  '/content/Project Files/Testing Data/X_test2.npy',
#  '/content/Project Files/Training Data/common_time.npy',
#  '/content/Project Files/Training Data/ground_truth.npy',
#  '/content/Project Files/Training Data/labels.npy',
#  '/content/Project Files/Training Data/meteo_data.csv',
#  '/content/Project Files/Training Data/X1.npy',
#  '/content/Project Files/Training Data/X2.npy']

# %%
import pandas as pd
import os

# File paths and corresponding column names
file_columns = [('/content/Project Files/Training Data/common_time.npy', 'common_time'),
                ('/content/Project Files/Training Data/ground_truth.npy', 'ground_truth'),
                ('/content/Project Files/Training Data/labels.npy', 'labels'),
                ('/content/Project Files/Training Data/meteo_data.csv', 'meteo_data')]
# Create an empty DataFrame
combined_df = pd.DataFrame()

# Load and add data to the DataFrame
for file_path, column_name in file_columns:
    if file_path.endswith('.npy'):
        data = np.load(file_path, allow_pickle=True)
        df = pd.DataFrame(data, columns=[column_name])
        combined_df = pd.concat([combined_df, df], axis=1)
    elif file_path.endswith('.csv'):
        df = pd.read_csv(file_path)
        df.columns = [f"{column_name}_{col}" for col in df.columns]
        combined_df = pd.concat([combined_df, df], axis=1)

# Display the combined DataFrame
print("Combined DataFrame:")

#remove one of the date columns
combined_df = combined_df.drop('meteo_data_time', axis=1)
print(combined_df.shape)
combined_df.head(5)
# Out:
# Combined DataFrame:
# (10000, 6)
#           common_time  ground_truth  labels  meteo_data_Air_temp  \
# 0 2021-12-06 08:50:00          21.0   132.0                  1.6
# 1 2021-12-06 09:10:00          34.0   126.0                  1.8
# 2 2021-12-06 09:20:00          52.0   136.0                  1.7
# 3 2021-12-06 09:30:00          70.0   143.0                  1.8
# 4 2021-12-06 09:50:00          82.0   134.0                  1.9
#
#    meteo_data_Wind_speed  meteo_data_Wind_dir
# 0                    1.0                  324
# 1                    1.2                  331
# 2                    1.7                  329
# 3                    1.3                  325
# 4                    1.0                  326

# %%
# Load images
x1 = np.load('/content/Project Files/Training Data/X1.npy')
x2 = np.load('/content/Project Files/Training Data/X2.npy')

# %%
# Create a subplot with two rows and five columns
fig, axes = plt.subplots(2, 5, figsize=(15, 5))

# Display images in the subplot
for i in range(5):
    axes[0, i].imshow(x1[i])
    axes[0, i].axis('off')
    axes[1, i].imshow(x2[i])
    axes[1, i].axis('off')

plt.show()

print("x1 shape: ", x1.shape)
print("x2 shape: ", x2.shape)
# Out:
# x1 shape:  (10000, 250, 250, 3)
# x2 shape:  (10000, 250, 250, 3)

# %%
# Resizing the images to new dimensions

# take only every two images and combined_df
x1 = x1[::2]
x2 = x2[::2]
combined_df = combined_df.iloc[::2]

new_dim = 100
image_crop_percent = 0 # (top, bottom, left, right)
side_dim_scaled = (new_dim, int(new_dim * (1 - image_crop_percent)))

x1_resized = np.array([cv2.resize(img, (new_dim, new_dim)) for img in x1])
del x1
# crop the images
x1_resized = x1_resized[:, 0:int(x1_resized.shape[1]*(1-image_crop_percent))]

x2_resized = np.array([cv2.resize(img, (new_dim, new_dim)) for img in x2])
del x2
# crop the images
x2_resized = x2_resized[:, 0:int(x2_resized.shape[1]*(1-image_crop_percent))]

# normalize the images

x1_resized = x1_resized / 255.0
x2_resized = x2_resized / 255.0

new_dim = (x1_resized.shape[1], x1_resized.shape[2])

# %%
print("x1_resized shape: ", x1_resized.shape)
print("x2_resized shape: ", x2_resized.shape)

# Create a subplot with two rows and five columns
fig, axes = plt.subplots(2, 5, figsize=(10, 5))

# Display images in the subplot
for i in range(5):
    axes[0, i].imshow(x1_resized[i])
    axes[0, i].axis('off')
    axes[1, i].imshow(x2_resized[i])
    axes[1, i].axis('off')

plt.show()
# Out:
# x1_resized shape:  (3334, 100, 100, 3)
# x2_resized shape:  (3334, 100, 100, 3)

# %%
add_mean_gt = False

# %%
#Split data
from datetime import timedelta

def date_to_cyclic(day, month, hour):
    c_day = np.cos(day * (2 * np.pi / 31))
    s_day = np.sin(day * (2 * np.pi / 31))
    c_month = np.cos(month * (2 * np.pi / 12))
    s_month = np.sin(month * (2 * np.pi / 12))
    c_hour = np.cos(hour * (2 * np.pi / 24))
    s_hour = np.sin(hour * (2 * np.pi / 24))

    return c_day, s_day, c_month, s_month, c_hour, s_hour

def split_train_test(data, train_test_ratio):
    train_size = int(len(data) * train_test_ratio)
    return data[:train_size], data[train_size:]

def create_train_test(train_test_ratio):

    date = combined_df['common_time']
    # convert to datetime
    date = pd.to_datetime(date)
    # extract the month
    month = date.dt.month
    # extract the day
    day = date.dt.day
    # extract the hour
    hour = date.dt.hour

    # extract the minutes
    minute = date.dt.minute

    # convert to cyclic
    c_day, s_day, c_month, s_month, c_hour, s_hour = date_to_cyclic(day, month, hour)
    
    columns = ['meteo_data_Wind_speed', 'meteo_data_Wind_dir', 'meteo_data_Air_temp','ground_truth']
    meteo_data = combined_df[columns]
    meteo_data = np.array(meteo_data)

    # Get the average ground_truth of the past hour, and store it as a new value
    avg_hour_ground_truth = [meteo_data[0, 3]]
    last_ground_truths = [meteo_data[0, 3]]

    for i in range(1, len(combined_df)):
        last_ground_truths.append(meteo_data[i-1, 3])

        current_date = date.iloc[i]
        time_objective = current_date - timedelta(hours=3)

        this_hour_ground_truth = [meteo_data[i, 3]]
        j = 1
        current_date = date.iloc[i - j]

        while current_date > time_objective:

            this_hour_ground_truth.append(meteo_data[i-j, 3])

            if i-j >= 0:
              j += 1
              current_date = date.iloc[i - j]
            else:
              break
        
        avg_hour_ground_truth.append(np.mean(this_hour_ground_truth))

    avg_hour_ground_truth = np.array(avg_hour_ground_truth)
    last_ground_truths = np.array(last_ground_truths)

    # Add cyclic date to meteo_data
    if add_mean_gt : 
        meteo_data = np.concatenate((meteo_data, c_day[:, None], s_day[:, None], c_month[:, None], s_month[:, None], c_hour[:, None], s_hour[:, None], avg_hour_ground_truth[:, None]), axis=1)
    else:
        meteo_data = np.concatenate((meteo_data, c_day[:, None], s_day[:, None], c_month[:, None], s_month[:, None], c_hour[:, None], s_hour[:, None]), axis=1)
        
    labels = combined_df['labels']
    labels = np.array(labels)

    train_x1, test_x1 = split_train_test(x1_resized, train_test_ratio)
    train_x2, test_x2 = split_train_test(x2_resized, train_test_ratio)

    train_data, test_data = split_train_test(meteo_data, train_test_ratio)

    y_train, y_test = split_train_test(labels, train_test_ratio)

    X_images_train = np.stack((train_x1, train_x2), 1)
    X_images_test = np.stack((test_x1, test_x2), 1)

    # Shuffle the data for training
    idx = np.random.permutation(len(X_images_train))

    X_images_train, X_data_train, y_train = X_images_train[idx], train_data[idx], y_train[idx]

    return X_images_train, X_data_train, X_images_test, test_data, y_train, y_test


train_test_ratio = 0.9

X_images_train, X_data_train, X_images_test, X_data_test, y_train, y_test = create_train_test(train_test_ratio)

print("X_images_train shape:", X_images_train.shape)
print("X_data_train shape:", X_data_train.shape)
print("X_images_test shape:", X_images_test.shape)
print("X_data_test shape:", X_data_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

del x1_resized
del x2_resized
# Out:
# <ipython-input-7-33d9095eb554>:70: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   meteo_data = np.concatenate((meteo_data, c_day[:, None], s_day[:, None], c_month[:, None], s_month[:, None], c_hour[:, None], s_hour[:, None], day[:, None], month[:, None], hour[:, None]), axis=1)
# X_images_train shape: (3000, 2, 100, 100, 3)
# X_data_train shape: (3000, 13)
# X_images_test shape: (334, 2, 100, 100, 3)
# X_data_test shape: (334, 13)
# y_train shape: (3000,)
# y_test shape: (334,)

# %%
# Plot the cyclid data, use month and day hour as x-axis

day_y = X_data_train[:, -4]
month_y = X_data_train[:, -3]
hour_y = X_data_train[:, -2]

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot cosine and sine of day
axes[0].scatter(day_y, X_data_train[:, 4], label='c_day')
axes[0].scatter(day_y, X_data_train[:, 5], label='s_day')
axes[0].set_xlabel('day')
axes[0].set_ylabel('value')
axes[0].set_title('Cosine and sine of day')
axes[0].legend()

# Plot cosine and sine of month
axes[1].scatter(month_y, X_data_train[:, 6], label='c_month')
axes[1].scatter(month_y, X_data_train[:, 7], label='s_month')
axes[1].set_xlabel('month')
axes[1].set_ylabel('value')
axes[1].set_title('Cosine and sine of month')
axes[1].legend()

# Plot cosine and sine of hour
axes[2].scatter(hour_y, X_data_train[:, 8], label='c_hour')
axes[2].scatter(hour_y, X_data_train[:, 9], label='s_hour')
axes[2].set_xlabel('hour')
axes[2].set_ylabel('value')
axes[2].set_title('Cosine and sine of hour')
axes[2].legend()

plt.show()

# %%
# plot a lineplot of text values with the Ground Truth, add date as x axis dd/mm

import seaborn as sns

days = X_data_test[:, -3]
months = X_data_test[:, -2]

# Create a new column with the date
dates = []
for i in range(len(days)):
    dates.append(str(int(days[i])) + '/' + str(int(months[i])))
dates = np.array(dates)

# Create a new column with the Ground Truth (X_data_test[:, 3])
ground_truth = []
for i in range(len(days)):
    ground_truth.append(X_data_test[:, 3][i])
ground_truth = np.array(ground_truth)

# plot the lineplot
plt.figure(figsize=(15, 5))
# don't display confidence interval
sns.lineplot(x=dates, y=ground_truth, ci=None)
plt.xlabel('Date')
plt.ylabel('Ground Truth')
plt.title('Ground Truth over time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1732/3610612401.py in <module>
#       1 # plot a lineplot with the Ground Truth, add date as x axis dd/mm
#       2
# ----> 3 plt.figure(figsize=(15, 5))
#       4 plt.plot(combined_df['common_time'], combined_df['ground_truth'])
#       5 plt.xlabel('Date')
#
# NameError: name 'plt' is not defined

# %%
# print the first 2 images with labels and corresponding wind speed

fig, axes = plt.subplots(2, 4, figsize=(10, 5))

# Display images in the subplot
for i in range(4):

    axes[0, i].imshow(X_images_train[i][0])
    axes[0, i].axis('off')
    # plot title as label and wind speed
    axes[0, i].set_title("Label: {} \nWind speed: {}\nWind direction: {}\nAir temp: {}\nGround Truth: {}".format(y_train[i], X_data_train[i,0],X_data_train[i,1],X_data_train[i,2],X_data_train[i,3]))
    axes[1, i].imshow(X_images_train[i][1])
    axes[1, i].axis('off')
    axes[1, i].set_title("Label: {} \nWind speed: {}\nWind direction: {}\nAir temp: {}\nGround Truth: {}".format(y_train[i], X_data_train[i,0],X_data_train[i,1],X_data_train[i,2],X_data_train[i,3]))

plt.tight_layout()
plt.show()

# %%
plt.plot(X_data_test[:, 3])

# %%
plt.plot(X_data_test[:, -1])

# %% [markdown]
# ChatGPT model

# %%
# !pip install -U -q tensorflow-addons

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import (
    Input,
    Reshape,
    LSTM,
    Dense,
    TimeDistributed,
    Conv2D,
    MaxPooling2D,
    Dropout,
    Flatten,
    GRU,
    ConvLSTM2D,
    MultiHeadAttention,
    LayerNormalization,
    GlobalMaxPooling2D,
    Activation,
    GlobalAvgPool2D,
    DepthwiseConv2D
)
import tensorflow_addons as tfa
from tensorflow.keras import layers
from tensorflow import keras
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
#Add a dimension to X_data_train and X_data_test to make them n,1,13 instead of n,13
X_data_train = np.expand_dims(X_data_train, axis=1)
X_data_test = np.expand_dims(X_data_test, axis=1)

channels = 3

# %% [markdown]
# New Transformer code :

# %%
# define the parameters
lr = 0.001
use_gru = False
use_convlstm = False
use_ConvMixer = True

convDepth = 5
convFilters = 64
k_size = 5

# %%
input_image = Input(shape=(2, new_dim[0], new_dim[1], channels), name='image_input')
input_data = Input(shape=(X_data_train.shape[2],), name='weather_data_input')

# Reshape data input for LSTM
input_data = Reshape((1, -1))(input_data)

data_input = LSTM(32, return_sequences=True)(input_data)
data_input = Dense(32, activation='relu')(data_input)
data_input = Dense(8, activation='relu')(data_input)

# CNN Block 1
if not use_ConvMixer:
  image_conv = TimeDistributed(Conv2D(8, kernel_size=(3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)))(input_image)
  image_conv = TimeDistributed(MaxPooling2D(pool_size=2))(image_conv)
  image_conv = TimeDistributed(Conv2D(8, kernel_size=3, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)))(image_conv)
  image_conv = TimeDistributed(MaxPooling2D(pool_size=2))(image_conv)

  # Add dropout to reduce overfitting
  image_conv = TimeDistributed(Dropout(0.1))(image_conv)

else :

    # Extract patch embeddings for both images.
    x = TimeDistributed(Conv2D(32, kernel_size=2, strides=2, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(input_image)
    x = TimeDistributed(Activation("gelu"))(x)

    # ConvMixer blocks.
    for _ in range(convDepth):
       # Apply time distributed conv mixer block.
      x0 = x
      x = TimeDistributed(DepthwiseConv2D(kernel_size=k_size, padding="same", kernel_regularizer=tf.keras.regularizers.l2(0.001)))(x)
      tmp = TimeDistributed(Activation("gelu"))(x)
      x = TimeDistributed(layers.Add())([tmp, x0])  # Residual.
      x = TimeDistributed(Dropout(0.1))(x)

      # Pointwise convolution.
      x = TimeDistributed(Conv2D(convFilters, kernel_size=1, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(x)
      x = TimeDistributed(Activation("gelu"))(x)

    # Classification block.
    print(x.shape)
    image_conv = ConvLSTM2D(16, kernel_size=3, activation='relu', return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
    image_conv = TimeDistributed(MaxPooling2D(pool_size=2))(image_conv)
    image_conv = ConvLSTM2D(16, kernel_size=3, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(image_conv)
    image_conv = MaxPooling2D(pool_size=2)(image_conv)
    image_conv = Dropout(0.1)(image_conv)
    print(image_conv.shape)


# CNN Block 2

if not use_convlstm : 
  pass
  #image_conv = TimeDistributed(Conv2D(16, kernel_size=3, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)))(image_conv)
  #image_conv = TimeDistributed(MaxPooling2D(pool_size=2))(image_conv)
  #image_conv = TimeDistributed(Conv2D(16, kernel_size=3, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))(image_conv)
  #image_conv = TimeDistributed(MaxPooling2D(pool_size=2))(image_conv)
  #image_conv = TimeDistributed(Dropout(0.1))(image_conv)
else : 
  image_conv = ConvLSTM2D(16, kernel_size=3, activation='relu', return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(0.001))(image_conv)
  image_conv = ConvLSTM2D(16, kernel_size=3, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(image_conv)
  image_conv = MaxPooling2D(pool_size=2)(image_conv)
  image_conv = Dropout(0.1)(image_conv)

# Flattening and Reshaping for LSTM
flt = TimeDistributed(Flatten())(image_conv)
flt = Reshape((1, -1))(flt)

# Concatenating CNN and data input
concat = tf.keras.layers.concatenate([flt, data_input])

# LSTM
lstm1 = tf.keras.layers.LSTM(32, activation='relu', return_sequences=False)(concat)
lstm1 = Reshape((1, -1))(lstm1)

# GRU
gru_output = GRU(32, activation='relu', return_sequences=False)(concat)
gru_output = Reshape((1, -1))(gru_output)

if use_gru:
    final_hidden = gru_output
else : 
    final_hidden = lstm1

# Final Dense Layers
dense1 = Dense(200, activation='relu')(final_hidden)
dense1 = Dropout(0.3)(dense1)
dense1 = Dense(100, activation='relu')(dense1)
dense1 = Dropout(0.3)(dense1)
dense1 = Dense(50, activation='relu')(dense1)
dense1 = Dropout(0.3)(dense1)
dense1 = Dense(1, activation='relu')(dense1)
dense1 = Flatten()(dense1)

model = tf.keras.models.Model(inputs=[input_image, input_data], outputs=dense1)
# Out:
# (None, 2, 50, 50, 64)
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (None, 11, 11, 16)

# %% [markdown]
# Run model :

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image

# compile the model and use mse as loss function, use as metric accuracy or mse itself 
optimizertfa = tfa.optimizers.AdamW(
        learning_rate=lr, weight_decay=0.0001
    )

#model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(lr=lr), metrics=['mse'])
model.compile(loss='mse', optimizer=optimizertfa, metrics=['mse'])

print('Graphical schematic of the compiled network')
print()
model.summary()

plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')
Image(filename='model.png')
# Out:
# Graphical schematic of the compiled network
#
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(None, 2, 100, 100  0           []
#                                 , 3)]
#
#  time_distributed_66 (TimeDistr  (None, 2, 50, 50, 3  416        ['image_input[0][0]']
#  ibuted)                        2)
#
#  time_distributed_67 (TimeDistr  (None, 2, 50, 50, 3  0          ['time_distributed_66[1][0]']
#  ibuted)                        2)
#
#  time_distributed_68 (TimeDistr  (None, 2, 50, 50, 3  832        ['time_distributed_67[1][0]']
#  ibuted)                        2)
#
#  time_distributed_69 (TimeDistr  (None, 2, 50, 50, 3  0          ['time_distributed_68[1][0]']
#  ibuted)                        2)
#
#  time_distributed_70 (TimeDistr  (None, 2, 50, 50, 3  0          ['time_distributed_69[1][0]',
#  ibuted)                        2)                                'time_distributed_67[1][0]']
#
#  time_distributed_71 (TimeDistr  (None, 2, 50, 50, 3  0          ['time_distributed_70[1][0]']
#  ibuted)                        2)
#
#  time_distributed_72 (TimeDistr  (None, 2, 50, 50, 6  2112       ['time_distributed_71[1][0]']
#  ibuted)                        4)
#
#  time_distributed_73 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_72[1][0]']
#  ibuted)                        4)
#
#  time_distributed_74 (TimeDistr  (None, 2, 50, 50, 6  1664       ['time_distributed_73[1][0]']
#  ibuted)                        4)
#
#  time_distributed_75 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_74[1][0]']
#  ibuted)                        4)
#
#  time_distributed_76 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_75[1][0]',
#  ibuted)                        4)                                'time_distributed_73[1][0]']
#
#  time_distributed_77 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_76[1][0]']
#  ibuted)                        4)
#
#  time_distributed_78 (TimeDistr  (None, 2, 50, 50, 6  4160       ['time_distributed_77[1][0]']
#  ibuted)                        4)
#
#  time_distributed_79 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_78[1][0]']
#  ibuted)                        4)
#
#  time_distributed_80 (TimeDistr  (None, 2, 50, 50, 6  1664       ['time_distributed_79[1][0]']
#  ibuted)                        4)
#
#  time_distributed_81 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_80[1][0]']
#  ibuted)                        4)
#
#  time_distributed_82 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_81[1][0]',
#  ibuted)                        4)                                'time_distributed_79[1][0]']
#
#  time_distributed_83 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_82[1][0]']
#  ibuted)                        4)
#
#  time_distributed_84 (TimeDistr  (None, 2, 50, 50, 6  4160       ['time_distributed_83[1][0]']
#  ibuted)                        4)
#
#  time_distributed_85 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_84[1][0]']
#  ibuted)                        4)
#
#  time_distributed_86 (TimeDistr  (None, 2, 50, 50, 6  1664       ['time_distributed_85[1][0]']
#  ibuted)                        4)
#
#  time_distributed_87 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_86[1][0]']
#  ibuted)                        4)
#
#  time_distributed_88 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_87[1][0]',
#  ibuted)                        4)                                'time_distributed_85[1][0]']
#
#  time_distributed_89 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_88[1][0]']
#  ibuted)                        4)
#
#  time_distributed_90 (TimeDistr  (None, 2, 50, 50, 6  4160       ['time_distributed_89[1][0]']
#  ibuted)                        4)
#
#  time_distributed_91 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_90[1][0]']
#  ibuted)                        4)
#
#  time_distributed_92 (TimeDistr  (None, 2, 50, 50, 6  1664       ['time_distributed_91[1][0]']
#  ibuted)                        4)
#
#  time_distributed_93 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_92[1][0]']
#  ibuted)                        4)
#
#  time_distributed_94 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_93[1][0]',
#  ibuted)                        4)                                'time_distributed_91[1][0]']
#
#  time_distributed_95 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_94[1][0]']
#  ibuted)                        4)
#
#  time_distributed_96 (TimeDistr  (None, 2, 50, 50, 6  4160       ['time_distributed_95[1][0]']
#  ibuted)                        4)
#
#  time_distributed_97 (TimeDistr  (None, 2, 50, 50, 6  0          ['time_distributed_96[1][0]']
#  ibuted)                        4)
#
#  conv_lstm2d_4 (ConvLSTM2D)     (None, 2, 48, 48, 1  46144       ['time_distributed_97[1][0]']
#                                 6)
#
#  time_distributed_98 (TimeDistr  (None, 2, 24, 24, 1  0          ['conv_lstm2d_4[1][0]']
#  ibuted)                        6)
#
#  conv_lstm2d_5 (ConvLSTM2D)     (None, 22, 22, 16)   18496       ['time_distributed_98[1][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 11, 11, 16)  0           ['conv_lstm2d_5[1][0]']
#
#  input_3 (InputLayer)           [(None, 1, 13)]      0           []
#
#  dropout_23 (Dropout)           (None, 11, 11, 16)   0           ['max_pooling2d_3[1][0]']
#
#  lstm_4 (LSTM)                  (None, 1, 32)        5888        ['input_3[0][0]']
#
#  time_distributed_99 (TimeDistr  (None, 11, 176)     0           ['dropout_23[1][0]']
#  ibuted)
#
#  dense_12 (Dense)               (None, 1, 32)        1056        ['lstm_4[1][0]']
#
#  reshape_9 (Reshape)            (None, 1, 1936)      0           ['time_distributed_99[1][0]']
#
#  dense_13 (Dense)               (None, 1, 8)         264         ['dense_12[1][0]']
#
#  concatenate_2 (Concatenate)    (None, 1, 1944)      0           ['reshape_9[1][0]',
#                                                                   'dense_13[1][0]']
#
#  lstm_5 (LSTM)                  (None, 32)           253056      ['concatenate_2[1][0]']
#
#  reshape_10 (Reshape)           (None, 1, 32)        0           ['lstm_5[1][0]']
#
#  dense_14 (Dense)               (None, 1, 200)       6600        ['reshape_10[1][0]']
#
#  dropout_24 (Dropout)           (None, 1, 200)       0           ['dense_14[1][0]']
#
#  dense_15 (Dense)               (None, 1, 100)       20100       ['dropout_24[1][0]']
#
#  dropout_25 (Dropout)           (None, 1, 100)       0           ['dense_15[1][0]']
#
#  dense_16 (Dense)               (None, 1, 50)        5050        ['dropout_25[1][0]']
#
#  dropout_26 (Dropout)           (None, 1, 50)        0           ['dense_16[1][0]']
#
#  dense_17 (Dense)               (None, 1, 1)         51          ['dropout_26[1][0]']
#
#  flatten_5 (Flatten)            (None, 1)            0           ['dense_17[1][0]']
#
# ==================================================================================================
# Total params: 383,361
# Trainable params: 383,361
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error

rmse_list = []

def reset_model(model):

    model_copy = tf.keras.models.clone_model(model)
    model_copy.set_weights(model.get_weights())

    return model_copy


indx = 1
for i in range(indx):
    print('Training iteration: ', i+1)
    print()

    model_copy = reset_model(model)
    model_copy.compile(optimizer='adam', loss='mean_squared_error') # default lr = 0.001

    history = model_copy.fit([X_images_train, X_data_train], y_train, shuffle=True, epochs=40, batch_size=128, verbose = 1, validation_data=([X_images_test, X_data_test], y_test))
    print()
    print('Training rmse: ', np.sqrt(history.history['loss'][-1]))
    print('Validation rmse: ', np.sqrt(history.history['val_loss'][-1]))

    y_pred = model_copy.predict([X_images_test, X_data_test])

    rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    print('Test accuracy: ', rmse)
    print()
    rmse_list.append(rmse)
    if i != indx -1 :
      del model_copy
      del history

#Averaging the test accuracy after 5 times training
print('Average test rmse: ', np.mean(rmse_list))
print('Standard deviation of test rmse: ', np.std(rmse_list))
# Out:
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Training iteration:  1
#
# Epoch 1/40
# 24/24 [==============================] - 35s 779ms/step - loss: 147696.5781 - val_loss: 40827.8750
# Epoch 2/40
# 24/24 [==============================] - 17s 721ms/step - loss: 82491.3359 - val_loss: 40717.4570
# Epoch 3/40
# 24/24 [==============================] - 17s 712ms/step - loss: 69819.0078 - val_loss: 39645.2617
# Epoch 4/40
# 24/24 [==============================] - 17s 704ms/step - loss: 49992.4414 - val_loss: 22050.6562
# Epoch 5/40
# 24/24 [==============================] - 17s 706ms/step - loss: 29903.7461 - val_loss: 22749.0215
# Epoch 6/40
# 24/24 [==============================] - 17s 710ms/step - loss: 28692.1328 - val_loss: 24076.4062
# Epoch 7/40
# 24/24 [==============================] - 17s 710ms/step - loss: 27223.5605 - val_loss: 22381.4336
# Epoch 8/40
# 24/24 [==============================] - 17s 711ms/step - loss: 27351.4805 - val_loss: 25602.8320
# Epoch 9/40
# 24/24 [==============================] - 17s 710ms/step - loss: 25422.2754 - val_loss: 22114.5547
# Epoch 10/40
# 24/24 [==============================] - 18s 736ms/step - loss: 24998.2070 - val_loss: 21174.3809
# Epoch 11/40
# 24/24 [==============================] - 17s 706ms/step - loss: 24458.8594 - val_loss: 21261.2617
# Epoch 12/40
# 24/24 [==============================] - 17s 708ms/step - loss: 23515.6621 - val_loss: 20715.2344
# Epoch 13/40
# 24/24 [==============================] - 17s 710ms/step - loss: 21297.2539 - val_loss: 21297.0410
# Epoch 14/40
# 24/24 [==============================] - 17s 711ms/step - loss: 21208.3691 - val_loss: 19583.1406
# Epoch 15/40
# 24/24 [==============================] - 17s 708ms/step - loss: 20203.8223 - val_loss: 20760.8301
# Epoch 16/40
# 24/24 [==============================] - 18s 737ms/step - loss: 19435.0371 - val_loss: 19271.3359
# Epoch 17/40
# 24/24 [==============================] - 17s 709ms/step - loss: 19424.1758 - val_loss: 18481.3906
# Epoch 18/40
# 24/24 [==============================] - 18s 737ms/step - loss: 17911.1484 - val_loss: 19075.9043
# Epoch 19/40
# 24/24 [==============================] - 17s 710ms/step - loss: 18028.3379 - val_loss: 19539.6191
# Epoch 20/40
# 24/24 [==============================] - 18s 738ms/step - loss: 17227.5547 - val_loss: 17143.0352
# Epoch 21/40
# 24/24 [==============================] - 17s 708ms/step - loss: 17450.5273 - val_loss: 16186.2158
# Epoch 22/40
# 24/24 [==============================] - 18s 737ms/step - loss: 16215.7158 - val_loss: 17808.2461
# Epoch 23/40
# 24/24 [==============================] - 17s 710ms/step - loss: 16071.8281 - val_loss: 16882.9531
# Epoch 24/40
# 24/24 [==============================] - 18s 736ms/step - loss: 15621.2812 - val_loss: 16014.4189
# Epoch 25/40
# 24/24 [==============================] - 17s 711ms/step - loss: 15831.9297 - val_loss: 15527.8027
# Epoch 26/40
# 24/24 [==============================] - 17s 710ms/step - loss: 15756.5332 - val_loss: 16961.5996
# Epoch 27/40
# 24/24 [==============================] - 17s 710ms/step - loss: 15461.7803 - val_loss: 19990.0625
# Epoch 28/40
# 24/24 [==============================] - 18s 737ms/step - loss: 16023.6709 - val_loss: 16644.5605
# Epoch 29/40
# 24/24 [==============================] - 17s 708ms/step - loss: 15636.9639 - val_loss: 16187.5693
# Epoch 30/40
# 24/24 [==============================] - 18s 737ms/step - loss: 15504.4863 - val_loss: 16133.7354
# Epoch 31/40
# 24/24 [==============================] - 17s 708ms/step - loss: 14929.2734 - val_loss: 16874.8359
# Epoch 32/40
# 24/24 [==============================] - 17s 710ms/step - loss: 14981.2471 - val_loss: 16889.6914
# Epoch 33/40
# 24/24 [==============================] - 17s 710ms/step - loss: 14936.1582 - val_loss: 15546.4502
# Epoch 34/40
# 24/24 [==============================] - 17s 709ms/step - loss: 14765.2363 - val_loss: 16501.3359
# Epoch 35/40
# 24/24 [==============================] - 17s 710ms/step - loss: 14885.4893 - val_loss: 15703.5244
# Epoch 36/40
# 24/24 [==============================] - 17s 708ms/step - loss: 15619.6797 - val_loss: 16157.9160
# Epoch 37/40
# 24/24 [==============================] - 17s 709ms/step - loss: 14309.9355 - val_loss: 16093.8545
# Epoch 38/40
# 24/24 [==============================] - 18s 734ms/step - loss: 14416.7266 - val_loss: 15563.5059
# Epoch 39/40
# 24/24 [==============================] - 17s 709ms/step - loss: 13998.3252 - val_loss: 16263.3672
# Epoch 40/40
# 24/24 [==============================] - 18s 735ms/step - loss: 13974.6602 - val_loss: 15058.9443
#
# Training rmse:  118.2144667807202
# Validation rmse:  122.71489044096279
# 11/11 [==============================] - 2s 66ms/step
# Test accuracy:  122.71335317042903
#
# Average test rmse:  122.71335317042903
# Standard deviation of test rmse:  0.0

# %%
# Plot the training and validation loss

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.yscale('log')
plt.show()

# %%
# Plot the RMSE loss

plt.plot(np.sqrt(history.history['loss']), label='RMSE Training loss')
plt.plot(np.sqrt(history.history['val_loss']), label='RMSE Validation loss')
plt.legend()
plt.show()

# %%
plt.plot(y_pred, label = 'Ypred')
plt.plot(y_test, label = 'Ytest')
plt.legend()
