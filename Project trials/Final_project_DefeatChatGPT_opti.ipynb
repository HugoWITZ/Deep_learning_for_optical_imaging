# %% [markdown]
# <a href="https://colab.research.google.com/github/Termote/Deep_learning_for_optical_imaging/blob/main/Final_project_DefeatChatGPT_opti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Data

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.models import Model
from keras.layers import Input, Activation
from keras.layers import Conv2D, MaxPooling2D,TimeDistributed, Concatenate, Conv3D, MaxPooling3D, BatchNormalization
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import Adam

from sklearn.model_selection import train_test_split

import cv2
import os
import gdown

# %%
# Download the data training folder
url = "https://drive.google.com/drive/folders/15tqljOBNINQ1nh54yFzhZvPcbRJi5RSd"
gdown.download_folder(url, quiet=True, use_cookies=False)
# Out:
# ['/content/Project Files/Data Description.docx',
#  '/content/Project Files/Project presentation.pdf',
#  '/content/Project Files/Sample_Network_GPT.ipynb',
#  '/content/Project Files/Training Data/common_time.npy',
#  '/content/Project Files/Training Data/ground_truth.npy',
#  '/content/Project Files/Training Data/labels.npy',
#  '/content/Project Files/Training Data/meteo_data.csv',
#  '/content/Project Files/Training Data/X1.npy',
#  '/content/Project Files/Training Data/X2.npy']

# %%
import pandas as pd
import os

# File paths and corresponding column names
file_columns = [('/content/Training Data/common_time.npy', 'common_time'),
                ('/content/Training Data/ground_truth.npy', 'ground_truth'),
                ('/content/Training Data/labels.npy', 'labels'),
                ('/content/Training Data/meteo_data.csv', 'meteo_data')]
# Create an empty DataFrame
combined_df = pd.DataFrame()

# Load and add data to the DataFrame
for file_path, column_name in file_columns:
    if file_path.endswith('.npy'):
        data = np.load(file_path, allow_pickle=True)
        df = pd.DataFrame(data, columns=[column_name])
        combined_df = pd.concat([combined_df, df], axis=1)
    elif file_path.endswith('.csv'):
        df = pd.read_csv(file_path)
        df.columns = [f"{column_name}_{col}" for col in df.columns]
        combined_df = pd.concat([combined_df, df], axis=1)

# Display the combined DataFrame
print("Combined DataFrame:")

#remove one of the date columns
combined_df = combined_df.drop('meteo_data_time', axis=1)
print(combined_df.shape)
combined_df.head(5)
# Out:
# Combined DataFrame:
# (10000, 6)
#           common_time  ground_truth  labels  meteo_data_Air_temp  \
# 0 2021-12-06 08:50:00          21.0   132.0                  1.6
# 1 2021-12-06 09:10:00          34.0   126.0                  1.8
# 2 2021-12-06 09:20:00          52.0   136.0                  1.7
# 3 2021-12-06 09:30:00          70.0   143.0                  1.8
# 4 2021-12-06 09:50:00          82.0   134.0                  1.9
#
#    meteo_data_Wind_speed  meteo_data_Wind_dir
# 0                    1.0                  324
# 1                    1.2                  331
# 2                    1.7                  329
# 3                    1.3                  325
# 4                    1.0                  326

# %%
# Load images
x1 = np.load('/content/Training Data/X1.npy')
x2 = np.load('/content/Training Data/X2.npy')

# %%
# Create a subplot with two rows and five columns
fig, axes = plt.subplots(2, 5, figsize=(15, 5))

# Display images in the subplot
for i in range(5):
    axes[0, i].imshow(x1[i])
    axes[0, i].axis('off')
    axes[1, i].imshow(x2[i])
    axes[1, i].axis('off')

plt.show()

print("x1 shape: ", x1.shape)
print("x2 shape: ", x2.shape)
# Out:
# x1 shape:  (10000, 250, 250, 3)
# x2 shape:  (10000, 250, 250, 3)

# %%
# Resizing the images to new dimensions

# take only every two images and combined_df
x1 = x1[::4]
x2 = x2[::4]
combined_df = combined_df.iloc[::4]

new_dim = 100
image_crop_percent = 0 # (top, bottom, left, right)
side_dim_scaled = (new_dim, int(new_dim * (1 - image_crop_percent)))

x1_resized = np.array([cv2.resize(img, (new_dim, new_dim)) for img in x1])
del x1
# crop the images
x1_resized = x1_resized[:, 0:int(x1_resized.shape[1]*(1-image_crop_percent))]

x2_resized = np.array([cv2.resize(img, (new_dim, new_dim)) for img in x2])
del x2
# crop the images
x2_resized = x2_resized[:, 0:int(x2_resized.shape[1]*(1-image_crop_percent))]

# normalize the images

x1_resized = x1_resized / 255.0
x2_resized = x2_resized / 255.0

new_dim = (x1_resized.shape[1], x1_resized.shape[2])

# %%
print("x1_resized shape: ", x1_resized.shape)
print("x2_resized shape: ", x2_resized.shape)

# Create a subplot with two rows and five columns
fig, axes = plt.subplots(2, 5, figsize=(10, 5))

# Display images in the subplot
for i in range(5):
    axes[0, i].imshow(x1_resized[i])
    axes[0, i].axis('off')
    axes[1, i].imshow(x2_resized[i])
    axes[1, i].axis('off')

plt.show()
# Out:
# x1_resized shape:  (2500, 100, 100, 3)
# x2_resized shape:  (2500, 100, 100, 3)

# %%
#Split data

def date_to_cyclic(day, month, hour):
    c_day = np.cos(day * (2 * np.pi / 31))
    s_day = np.sin(day * (2 * np.pi / 31))
    c_month = np.cos(month * (2 * np.pi / 12))
    s_month = np.sin(month * (2 * np.pi / 12))
    c_hour = np.cos(hour * (2 * np.pi / 24))
    s_hour = np.sin(hour * (2 * np.pi / 24))

    return c_day, s_day, c_month, s_month, c_hour, s_hour

def split_train_test(data, train_test_ratio):
    train_size = int(len(data) * train_test_ratio)
    return data[:train_size], data[train_size:]

def create_train_test(train_test_ratio):

    date = combined_df['common_time']
    # convert to datetime
    date = pd.to_datetime(date)
    # extract the month
    month = date.dt.month
    # extract the day
    day = date.dt.day
    # extract the hour
    hour = date.dt.hour

    # convert to cyclic
    c_day, s_day, c_month, s_month, c_hour, s_hour = date_to_cyclic(day, month, hour)
    
    columns = ['meteo_data_Wind_speed', 'meteo_data_Wind_dir', 'meteo_data_Air_temp','ground_truth']
    meteo_data = combined_df[columns]
    meteo_data = np.array(meteo_data)

    # Add cyclic date to meteo_data
    meteo_data = np.concatenate((meteo_data, c_day[:, None], s_day[:, None], c_month[:, None], s_month[:, None], c_hour[:, None], s_hour[:, None], day[:, None], month[:, None], hour[:, None]), axis=1)

    labels = combined_df['labels']
    labels = np.array(labels)

    train_x1, test_x1 = split_train_test(x1_resized, train_test_ratio)
    train_x2, test_x2 = split_train_test(x2_resized, train_test_ratio)

    train_data, test_data = split_train_test(meteo_data, train_test_ratio)

    y_train, y_test = split_train_test(labels, train_test_ratio)

    X_images_train = np.stack((train_x1, train_x2), 1)
    X_images_test = np.stack((test_x1, test_x2), 1)

    # Shuffle the data for training
    idx = np.random.permutation(len(X_images_train))

    X_images_train, X_data_train, y_train = X_images_train[idx], train_data[idx], y_train[idx]

    return X_images_train, X_data_train, X_images_test, test_data, y_train, y_test


train_test_ratio = 0.9

X_images_train, X_data_train, X_images_test, X_data_test, y_train, y_test = create_train_test(train_test_ratio)

print("X_images_train shape:", X_images_train.shape)
print("X_data_train shape:", X_data_train.shape)
print("X_images_test shape:", X_images_test.shape)
print("X_data_test shape:", X_data_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

del x1_resized
del x2_resized
# Out:
# <ipython-input-23-aa7e25dd19a4>:32: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   meteo_data = np.concatenate((meteo_data, c_day[:, None], s_day[:, None], c_month[:, None], s_month[:, None]), axis=1)
# X_images_train shape: (2250, 2, 100, 100, 3)
# X_data_train shape: (2250, 8)
# X_images_test shape: (250, 2, 100, 100, 3)
# X_data_test shape: (250, 8)
# y_train shape: (2250,)
# y_test shape: (250,)

# %%
# Plot the cyclid data, use month and day hour as x-axis

day_y = X_data_train[:, -3]
month_y = X_data_train[:, -2]
hour_y = X_data_train[:, -1]

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot cosine and sine of day
axes[0].scatter(day_y, X_data_train[:, 4], label='c_day')
axes[0].scatter(day_y, X_data_train[:, 5], label='s_day')
axes[0].set_xlabel('day')
axes[0].set_ylabel('value')
axes[0].set_title('Cosine and sine of day')
axes[0].legend()

# Plot cosine and sine of month
axes[1].plot(month_y, X_data_train[:, 6], label='c_month')
axes[1].plot(month_y, X_data_train[:, 7], label='s_month')
axes[1].set_xlabel('month')
axes[1].set_ylabel('value')
axes[1].set_title('Cosine and sine of month')
axes[1].legend()

# Plot cosine and sine of hour
axes[2].plot(hour_y, X_data_train[:, 8], label='c_hour')
axes[2].plot(hour_y, X_data_train[:, 9], label='s_hour')
axes[2].set_xlabel('hour')
axes[2].set_ylabel('value')
axes[2].set_title('Cosine and sine of hour')
axes[2].legend()

plt.show()

# %%
# print the first 2 images with labels and corresponding wind speed

fig, axes = plt.subplots(2, 4, figsize=(10, 5))

# Display images in the subplot
for i in range(4):

    axes[0, i].imshow(X_images_train[i][0])
    axes[0, i].axis('off')
    # plot title as label and wind speed
    axes[0, i].set_title("Label: {} \nWind speed: {}\nWind direction: {}\nAir temp: {}\nGround Truth: {}".format(y_train[i], X_data_train[i,0],X_data_train[i,1],X_data_train[i,2],X_data_train[i,3]))
    axes[1, i].imshow(X_images_train[i][1])
    axes[1, i].axis('off')
    axes[1, i].set_title("Label: {} \nWind speed: {}\nWind direction: {}\nAir temp: {}\nGround Truth: {}".format(y_train[i], X_data_train[i,0],X_data_train[i,1],X_data_train[i,2],X_data_train[i,3]))

plt.tight_layout()
plt.show()

# %% [markdown]
# ChatGPT model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, LSTM, Dense, Flatten, concatenate
import numpy as np

# %%
#Add a dimension to X_data_train and X_data_test to make them n,1,13 instead of n,13
X_data_train = np.expand_dims(X_data_train, axis=1)
X_data_test = np.expand_dims(X_data_test, axis=1)

# %%
channels = 3

#Add a dimension to X_data_train and X_data_test to make them n,1,13 instead of n,13
X_data_train = np.expand_dims(X_data_train, axis=1)
X_data_test = np.expand_dims(X_data_test, axis=1)

input_image = tf.keras.layers.Input(shape=(2,new_dim[0], new_dim[1], channels), name='image_input')

input_data = tf.keras.layers.Input(shape=(X_data_train.shape[2],), name='weather_data_input')

# Reshape data input for LSTM
input_data = tf.keras.layers.Reshape((1, -1))(input_data)
data_input = tf.keras.layers.LSTM(32, return_sequences=True)(input_data)
# Add dense layer to reduce dimensionality
data_input = tf.keras.layers.Dense(16, activation='relu')(data_input)
data_input = tf.keras.layers.Dense(8, activation='relu')(data_input)

# CNN Block 1
first_input = tf.keras.layers.TimeDistributed(Conv2D(8, kernel_size=3, activation='relu'))(input_image)
first_input = tf.keras.layers.TimeDistributed(MaxPooling2D(pool_size = 2))(first_input)
first_input = tf.keras.layers.TimeDistributed(Conv2D(16, kernel_size=3, activation='relu'))(first_input)
first_input = tf.keras.layers.TimeDistributed(MaxPooling2D(pool_size = 2))(first_input)

# CNN Block 2
first_input = tf.keras.layers.TimeDistributed(Conv2D(32, kernel_size=3, activation='relu'))(first_input)
first_input = tf.keras.layers.TimeDistributed(MaxPooling2D(pool_size = 2))(first_input)
first_input = tf.keras.layers.TimeDistributed(Conv2D(32, kernel_size=3, activation='relu'))(first_input)
first_input = tf.keras.layers.TimeDistributed(MaxPooling2D(pool_size = 2))(first_input)
first_input = tf.keras.layers.TimeDistributed(Conv2D(16, kernel_size=3, activation='relu'))(first_input)
first_input = tf.keras.layers.TimeDistributed(MaxPooling2D(pool_size = 2))(first_input)

# Flattening and Reshaping for LSTM
flt = tf.keras.layers.TimeDistributed(Flatten())(first_input)
flt = tf.keras.layers.Reshape((1, -1))(flt)

# Concatenating CNN and data input
concat = tf.keras.layers.concatenate([flt, data_input])

# LSTM
lstm1 = tf.keras.layers.LSTM(64, activation='relu', return_sequences=False)(concat)

# Output
dense1 = tf.keras.layers.Dense(32, activation='relu')(lstm1)
dense1 = tf.keras.layers.Dense(1, activation='relu')(dense1)

# Setting input and ouput of model
model = tf.keras.models.Model(inputs=[input_image, input_data], outputs=dense1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21240/908496785.py in <module>
#       1 channels = 3
#       2
# ----> 3 input_image = tf.keras.layers.Input(shape=(2,new_dim[0], new_dim[1], channels), name='image_input')
#       4
#       5 input_data = tf.keras.layers.Input(shape=(X_data_train.shape[1],), name='weather_data_input')
#
# NameError: name 'tf' is not defined

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image

# compile the model and use mse as loss function, use as metric accuracy or mse itself 
model.compile(optimizer='adam', loss='mean_squared_error')

print('Graphical schematic of the compiled network')
print()
model.summary()

plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')
Image(filename='model.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21240/1043800515.py in <module>
#       3
#       4 # compile the model and use mse as loss function, use as metric accuracy or mse itself
# ----> 5 model.compile(optimizer='adam', loss='mean_squared_error')
#       6
#       7 print('Graphical schematic of the compiled network')
#
# NameError: name 'model' is not defined

# %%
from sklearn.metrics import mean_squared_error

rmse_list = []

def reset_model(model):

    model_copy = tf.keras.models.clone_model(model)
    model_copy.set_weights(model.get_weights())

    return model_copy

for i in range(5):
    print('Training iteration: ', i+1)
    print()

    model_copy = reset_model(model)
    model_copy.compile(optimizer='adam', loss='mean_squared_error') # default lr = 0.001

    history = model_copy.fit([X_images_train, X_data_train], y_train, shuffle=True, epochs=50, batch_size=128, verbose = 2, validation_split=0.1)
    print()
    print('Training rmse: ', np.sqrt(history.history['loss'][-1]))
    print('Validation rmse: ', np.sqrt(history.history['val_loss'][-1]))

    y_pred = model_copy.predict([X_images_test, X_data_test])
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    print('Test accuracy: ', rmse)
    print()
    rmse_list.append(rmse)
    if i != 4 :
      del model_copy
      del history

#Averaging the test accuracy after 5 times training
print('Average test rmse: ', np.mean(rmse_list))
print('Standard deviation of test rmse: ', np.std(rmse_list))
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Training iteration:  1
#
# Epoch 1/50
# 16/16 - 6s - loss: 161736.4844 - val_loss: 156311.5625 - 6s/epoch - 347ms/step
# Epoch 2/50
# 16/16 - 1s - loss: 129227.3281 - val_loss: 74156.3594 - 658ms/epoch - 41ms/step
# Epoch 3/50
# 16/16 - 1s - loss: 66045.1250 - val_loss: 59707.6172 - 638ms/epoch - 40ms/step
# Epoch 4/50
# 16/16 - 1s - loss: 56453.9922 - val_loss: 50236.1055 - 633ms/epoch - 40ms/step
# Epoch 5/50
# 16/16 - 1s - loss: 49488.0547 - val_loss: 46089.3438 - 653ms/epoch - 41ms/step
# Epoch 6/50
# 16/16 - 1s - loss: 43802.5469 - val_loss: 43783.2070 - 635ms/epoch - 40ms/step
# Epoch 7/50
# 16/16 - 1s - loss: 41134.5547 - val_loss: 43726.3203 - 664ms/epoch - 42ms/step
# Epoch 8/50
# 16/16 - 1s - loss: 40151.3477 - val_loss: 43945.8164 - 664ms/epoch - 41ms/step
# Epoch 9/50
# 16/16 - 1s - loss: 39693.6562 - val_loss: 43808.9141 - 640ms/epoch - 40ms/step
# Epoch 10/50
# 16/16 - 1s - loss: 39189.0625 - val_loss: 43050.7109 - 640ms/epoch - 40ms/step
# Epoch 11/50
# 16/16 - 1s - loss: 38327.6250 - val_loss: 42624.2500 - 636ms/epoch - 40ms/step
# Epoch 12/50
# 16/16 - 1s - loss: 37412.3516 - val_loss: 41676.7539 - 641ms/epoch - 40ms/step
# Epoch 13/50
# 16/16 - 1s - loss: 36336.7656 - val_loss: 40414.8594 - 666ms/epoch - 42ms/step
# Epoch 14/50
# 16/16 - 1s - loss: 34642.3750 - val_loss: 39424.9141 - 676ms/epoch - 42ms/step
# Epoch 15/50
# 16/16 - 1s - loss: 31943.5859 - val_loss: 35033.6641 - 645ms/epoch - 40ms/step
# Epoch 16/50
# 16/16 - 1s - loss: 27374.6914 - val_loss: 28837.8438 - 632ms/epoch - 40ms/step
# Epoch 17/50
# 16/16 - 1s - loss: 21352.0430 - val_loss: 28821.6133 - 774ms/epoch - 48ms/step
# Epoch 18/50
# 16/16 - 1s - loss: 19961.8926 - val_loss: 25419.9531 - 813ms/epoch - 51ms/step
# Epoch 19/50
# 16/16 - 1s - loss: 18402.0332 - val_loss: 24847.9395 - 738ms/epoch - 46ms/step
# Epoch 20/50
# 16/16 - 1s - loss: 18031.7734 - val_loss: 24000.9785 - 635ms/epoch - 40ms/step
# Epoch 21/50
# 16/16 - 1s - loss: 17639.4453 - val_loss: 23699.6914 - 642ms/epoch - 40ms/step
# Epoch 22/50
# 16/16 - 1s - loss: 17420.5879 - val_loss: 25103.5117 - 630ms/epoch - 39ms/step
# Epoch 23/50
# 16/16 - 1s - loss: 17397.9199 - val_loss: 22866.5059 - 634ms/epoch - 40ms/step
# Epoch 24/50
# 16/16 - 1s - loss: 16795.8379 - val_loss: 23288.3340 - 660ms/epoch - 41ms/step
# Epoch 25/50
# 16/16 - 1s - loss: 16586.7207 - val_loss: 22421.1445 - 621ms/epoch - 39ms/step
# Epoch 26/50
# 16/16 - 1s - loss: 16369.5771 - val_loss: 21952.9395 - 632ms/epoch - 40ms/step
# Epoch 27/50
# 16/16 - 1s - loss: 16088.4570 - val_loss: 22125.0488 - 646ms/epoch - 40ms/step
# Epoch 28/50
# 16/16 - 1s - loss: 15834.4844 - val_loss: 24364.0117 - 624ms/epoch - 39ms/step
# Epoch 29/50
# 16/16 - 1s - loss: 15794.0674 - val_loss: 21449.1445 - 655ms/epoch - 41ms/step
# Epoch 30/50
# 16/16 - 1s - loss: 15412.3857 - val_loss: 21741.9219 - 631ms/epoch - 39ms/step
# Epoch 31/50
# 16/16 - 1s - loss: 15155.0830 - val_loss: 21130.7891 - 625ms/epoch - 39ms/step
# Epoch 32/50
# 16/16 - 1s - loss: 14945.9482 - val_loss: 22062.4746 - 637ms/epoch - 40ms/step
# Epoch 33/50
# 16/16 - 1s - loss: 14880.4990 - val_loss: 20741.3652 - 648ms/epoch - 41ms/step
# Epoch 34/50
# 16/16 - 1s - loss: 14571.5840 - val_loss: 20968.0898 - 634ms/epoch - 40ms/step
# Epoch 35/50
# 16/16 - 1s - loss: 14405.2246 - val_loss: 20686.9023 - 714ms/epoch - 45ms/step
# Epoch 36/50
# 16/16 - 1s - loss: 14795.6914 - val_loss: 20380.4570 - 789ms/epoch - 49ms/step
# Epoch 37/50
# 16/16 - 1s - loss: 14619.7363 - val_loss: 22025.3906 - 846ms/epoch - 53ms/step
# Epoch 38/50
# 16/16 - 1s - loss: 14310.4795 - val_loss: 20073.9648 - 686ms/epoch - 43ms/step
# Epoch 39/50
# 16/16 - 1s - loss: 14055.5820 - val_loss: 20925.9336 - 637ms/epoch - 40ms/step
# Epoch 40/50
# 16/16 - 1s - loss: 14024.4873 - val_loss: 19870.8711 - 662ms/epoch - 41ms/step
# Epoch 41/50
# 16/16 - 1s - loss: 14298.6768 - val_loss: 20935.3691 - 684ms/epoch - 43ms/step
# Epoch 42/50
# 16/16 - 1s - loss: 13790.3809 - val_loss: 19718.4219 - 658ms/epoch - 41ms/step
# Epoch 43/50
# 16/16 - 1s - loss: 13568.3809 - val_loss: 19708.0215 - 653ms/epoch - 41ms/step
# Epoch 44/50
# 16/16 - 1s - loss: 13604.8662 - val_loss: 19548.8125 - 638ms/epoch - 40ms/step
# Epoch 45/50
# 16/16 - 1s - loss: 13765.9268 - val_loss: 19826.6328 - 634ms/epoch - 40ms/step
# Epoch 46/50
# 16/16 - 1s - loss: 13440.3066 - val_loss: 19604.0449 - 657ms/epoch - 41ms/step
# Epoch 47/50
# 16/16 - 1s - loss: 13479.0635 - val_loss: 20088.0898 - 644ms/epoch - 40ms/step
# Epoch 48/50
# 16/16 - 1s - loss: 13693.8867 - val_loss: 19564.9902 - 625ms/epoch - 39ms/step
# Epoch 49/50
# 16/16 - 1s - loss: 13314.3936 - val_loss: 19410.3691 - 624ms/epoch - 39ms/step
# Epoch 50/50
# 16/16 - 1s - loss: 13239.5391 - val_loss: 19528.0469 - 602ms/epoch - 38ms/step
#
# Training rmse:  115.06319595118154
# Validation rmse:  139.74278827545984
# 8/8 [==============================] - 0s 6ms/step
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Test accuracy:  129.89385862037108
#
# Training iteration:  2
#
# Epoch 1/50
# 16/16 - 6s - loss: 161786.7500 - val_loss: 156383.3750 - 6s/epoch - 367ms/step
# Epoch 2/50
# 16/16 - 1s - loss: 129237.2969 - val_loss: 75127.2422 - 724ms/epoch - 45ms/step
# Epoch 3/50
# 16/16 - 1s - loss: 67246.0156 - val_loss: 59155.0977 - 761ms/epoch - 48ms/step
# Epoch 4/50
# 16/16 - 1s - loss: 56303.5273 - val_loss: 50697.3203 - 751ms/epoch - 47ms/step
# Epoch 5/50
# 16/16 - 1s - loss: 49918.4844 - val_loss: 46316.3125 - 676ms/epoch - 42ms/step
# Epoch 6/50
# 16/16 - 1s - loss: 43985.6914 - val_loss: 43770.8906 - 635ms/epoch - 40ms/step
# Epoch 7/50
# 16/16 - 1s - loss: 41283.7852 - val_loss: 43758.0430 - 624ms/epoch - 39ms/step
# Epoch 8/50
# 16/16 - 1s - loss: 40205.9258 - val_loss: 43832.6406 - 635ms/epoch - 40ms/step
# Epoch 9/50
# 16/16 - 1s - loss: 39574.3867 - val_loss: 43416.4844 - 627ms/epoch - 39ms/step
# Epoch 10/50
# 16/16 - 1s - loss: 38713.4883 - val_loss: 42396.0117 - 628ms/epoch - 39ms/step
# Epoch 11/50
# 16/16 - 1s - loss: 37147.1758 - val_loss: 41630.9062 - 625ms/epoch - 39ms/step
# Epoch 12/50
# 16/16 - 1s - loss: 34956.3984 - val_loss: 37329.6055 - 635ms/epoch - 40ms/step
# Epoch 13/50
# 16/16 - 1s - loss: 30376.3828 - val_loss: 33340.6445 - 641ms/epoch - 40ms/step
# Epoch 14/50
# 16/16 - 1s - loss: 25323.5977 - val_loss: 28373.3613 - 631ms/epoch - 39ms/step
# Epoch 15/50
# 16/16 - 1s - loss: 23447.5254 - val_loss: 32224.0020 - 631ms/epoch - 39ms/step
# Epoch 16/50
# 16/16 - 1s - loss: 21946.3340 - val_loss: 30203.7637 - 658ms/epoch - 41ms/step
# Epoch 17/50
# 16/16 - 1s - loss: 21073.5391 - val_loss: 25706.5820 - 657ms/epoch - 41ms/step
# Epoch 18/50
# 16/16 - 1s - loss: 20559.4180 - val_loss: 27574.9141 - 620ms/epoch - 39ms/step
# Epoch 19/50
# 16/16 - 1s - loss: 20357.4609 - val_loss: 26764.5586 - 627ms/epoch - 39ms/step
# Epoch 20/50
# 16/16 - 1s - loss: 19606.1641 - val_loss: 26445.9980 - 633ms/epoch - 40ms/step
# Epoch 21/50
# 16/16 - 1s - loss: 18884.3750 - val_loss: 24654.0117 - 817ms/epoch - 51ms/step
# Epoch 22/50
# 16/16 - 1s - loss: 18501.6738 - val_loss: 25877.7773 - 760ms/epoch - 47ms/step
# Epoch 23/50
# 16/16 - 1s - loss: 18693.9902 - val_loss: 25041.9805 - 753ms/epoch - 47ms/step
# Epoch 24/50
# 16/16 - 1s - loss: 19523.4551 - val_loss: 26172.3203 - 648ms/epoch - 41ms/step
# Epoch 25/50
# 16/16 - 1s - loss: 18133.6621 - val_loss: 23292.0996 - 657ms/epoch - 41ms/step
# Epoch 26/50
# 16/16 - 1s - loss: 17949.5020 - val_loss: 23686.7422 - 635ms/epoch - 40ms/step
# Epoch 27/50
# 16/16 - 1s - loss: 18576.5586 - val_loss: 22595.0391 - 641ms/epoch - 40ms/step
# Epoch 28/50
# 16/16 - 1s - loss: 17066.0898 - val_loss: 23602.4570 - 641ms/epoch - 40ms/step
# Epoch 29/50
# 16/16 - 1s - loss: 16782.0938 - val_loss: 23725.3418 - 631ms/epoch - 39ms/step
# Epoch 30/50
# 16/16 - 1s - loss: 16911.6719 - val_loss: 22267.2227 - 651ms/epoch - 41ms/step
# Epoch 31/50
# 16/16 - 1s - loss: 16788.3574 - val_loss: 23471.8574 - 664ms/epoch - 42ms/step
# Epoch 32/50
# 16/16 - 1s - loss: 17251.5449 - val_loss: 24186.7734 - 659ms/epoch - 41ms/step
# Epoch 33/50
# 16/16 - 1s - loss: 16013.0254 - val_loss: 21999.9336 - 644ms/epoch - 40ms/step
# Epoch 34/50
# 16/16 - 1s - loss: 15152.3809 - val_loss: 21308.5664 - 646ms/epoch - 40ms/step
# Epoch 35/50
# 16/16 - 1s - loss: 14840.0664 - val_loss: 21207.7129 - 647ms/epoch - 40ms/step
# Epoch 36/50
# 16/16 - 1s - loss: 14452.3604 - val_loss: 21056.9043 - 639ms/epoch - 40ms/step
# Epoch 37/50
# 16/16 - 1s - loss: 14541.4395 - val_loss: 21069.9297 - 654ms/epoch - 41ms/step
# Epoch 38/50
# 16/16 - 1s - loss: 14280.3955 - val_loss: 21271.4199 - 628ms/epoch - 39ms/step
# Epoch 39/50
# 16/16 - 1s - loss: 14168.7744 - val_loss: 20537.1328 - 763ms/epoch - 48ms/step
# Epoch 40/50
# 16/16 - 1s - loss: 13977.6016 - val_loss: 20657.3730 - 772ms/epoch - 48ms/step
# Epoch 41/50
# 16/16 - 1s - loss: 13839.9893 - val_loss: 20325.7285 - 761ms/epoch - 48ms/step
# Epoch 42/50
# 16/16 - 1s - loss: 13820.0508 - val_loss: 20149.3047 - 656ms/epoch - 41ms/step
# Epoch 43/50
# 16/16 - 1s - loss: 13713.9023 - val_loss: 20497.9785 - 637ms/epoch - 40ms/step
# Epoch 44/50
# 16/16 - 1s - loss: 13836.7939 - val_loss: 19967.1426 - 636ms/epoch - 40ms/step
# Epoch 45/50
# 16/16 - 1s - loss: 13743.5459 - val_loss: 20460.1875 - 647ms/epoch - 40ms/step
# Epoch 46/50
# 16/16 - 1s - loss: 13467.2539 - val_loss: 20224.9180 - 651ms/epoch - 41ms/step
# Epoch 47/50
# 16/16 - 1s - loss: 13401.4297 - val_loss: 19761.6680 - 637ms/epoch - 40ms/step
# Epoch 48/50
# 16/16 - 1s - loss: 13393.2344 - val_loss: 20289.1289 - 637ms/epoch - 40ms/step
# Epoch 49/50
# 16/16 - 1s - loss: 13450.5156 - val_loss: 19856.6348 - 634ms/epoch - 40ms/step
# Epoch 50/50
# 16/16 - 1s - loss: 13613.0410 - val_loss: 19493.3359 - 632ms/epoch - 40ms/step
#
# Training rmse:  116.674937392848
# Validation rmse:  139.61853722733238
# 8/8 [==============================] - 0s 6ms/step
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Test accuracy:  132.7051472932582
#
# Training iteration:  3
#
# Epoch 1/50
# 16/16 - 5s - loss: 161776.5000 - val_loss: 156507.7344 - 5s/epoch - 310ms/step
# Epoch 2/50
# 16/16 - 1s - loss: 129836.0547 - val_loss: 75773.0859 - 627ms/epoch - 39ms/step
# Epoch 3/50
# 16/16 - 1s - loss: 67032.2969 - val_loss: 58908.7148 - 654ms/epoch - 41ms/step
# Epoch 4/50
# 16/16 - 1s - loss: 56464.4023 - val_loss: 50672.7930 - 658ms/epoch - 41ms/step
# Epoch 5/50
# 16/16 - 1s - loss: 49837.1055 - val_loss: 46382.4141 - 650ms/epoch - 41ms/step
# Epoch 6/50
# 16/16 - 1s - loss: 44075.1875 - val_loss: 43770.4648 - 640ms/epoch - 40ms/step
# Epoch 7/50
# 16/16 - 1s - loss: 41240.4609 - val_loss: 43682.5586 - 746ms/epoch - 47ms/step
# Epoch 8/50
# 16/16 - 1s - loss: 40195.7227 - val_loss: 43946.4531 - 755ms/epoch - 47ms/step
# Epoch 9/50
# 16/16 - 1s - loss: 39699.5430 - val_loss: 43862.3281 - 734ms/epoch - 46ms/step
# Epoch 10/50
# 16/16 - 1s - loss: 39112.7734 - val_loss: 43110.4609 - 632ms/epoch - 39ms/step
# Epoch 11/50
# 16/16 - 1s - loss: 38431.6953 - val_loss: 42573.2266 - 621ms/epoch - 39ms/step
# Epoch 12/50
# 16/16 - 1s - loss: 37682.7109 - val_loss: 42043.2539 - 656ms/epoch - 41ms/step
# Epoch 13/50
# 16/16 - 1s - loss: 36705.5352 - val_loss: 41181.1094 - 644ms/epoch - 40ms/step
# Epoch 14/50
# 16/16 - 1s - loss: 35424.2031 - val_loss: 39892.3281 - 631ms/epoch - 39ms/step
# Epoch 15/50
# 16/16 - 1s - loss: 33309.7188 - val_loss: 36507.2539 - 653ms/epoch - 41ms/step
# Epoch 16/50
# 16/16 - 1s - loss: 29294.0332 - val_loss: 31302.2480 - 632ms/epoch - 39ms/step
# Epoch 17/50
# 16/16 - 1s - loss: 22954.8613 - val_loss: 26782.6445 - 648ms/epoch - 41ms/step
# Epoch 18/50
# 16/16 - 1s - loss: 20078.3730 - val_loss: 25270.6094 - 631ms/epoch - 39ms/step
# Epoch 19/50
# 16/16 - 1s - loss: 18761.7266 - val_loss: 24205.8262 - 636ms/epoch - 40ms/step
# Epoch 20/50
# 16/16 - 1s - loss: 17968.6074 - val_loss: 24303.8828 - 635ms/epoch - 40ms/step
# Epoch 21/50
# 16/16 - 1s - loss: 17543.8086 - val_loss: 23267.2129 - 648ms/epoch - 40ms/step
# Epoch 22/50
# 16/16 - 1s - loss: 17455.5020 - val_loss: 23843.3770 - 644ms/epoch - 40ms/step
# Epoch 23/50
# 16/16 - 1s - loss: 17048.1543 - val_loss: 22790.3379 - 623ms/epoch - 39ms/step
# Epoch 24/50
# 16/16 - 1s - loss: 16869.7305 - val_loss: 24807.4258 - 650ms/epoch - 41ms/step
# Epoch 25/50
# 16/16 - 1s - loss: 16528.0918 - val_loss: 22087.8086 - 710ms/epoch - 44ms/step
# Epoch 26/50
# 16/16 - 1s - loss: 16271.6484 - val_loss: 22457.4043 - 735ms/epoch - 46ms/step
# Epoch 27/50
# 16/16 - 1s - loss: 16364.3154 - val_loss: 21705.6621 - 775ms/epoch - 48ms/step
# Epoch 28/50
# 16/16 - 1s - loss: 15820.2207 - val_loss: 21258.1973 - 697ms/epoch - 44ms/step
# Epoch 29/50
# 16/16 - 1s - loss: 15484.8955 - val_loss: 21010.0547 - 638ms/epoch - 40ms/step
# Epoch 30/50
# 16/16 - 1s - loss: 15279.9775 - val_loss: 21047.3008 - 643ms/epoch - 40ms/step
# Epoch 31/50
# 16/16 - 1s - loss: 15198.2344 - val_loss: 20763.5996 - 632ms/epoch - 39ms/step
# Epoch 32/50
# 16/16 - 1s - loss: 14973.0107 - val_loss: 21081.1641 - 638ms/epoch - 40ms/step
# Epoch 33/50
# 16/16 - 1s - loss: 15012.5771 - val_loss: 20403.4336 - 637ms/epoch - 40ms/step
# Epoch 34/50
# 16/16 - 1s - loss: 14713.1006 - val_loss: 20579.9648 - 621ms/epoch - 39ms/step
# Epoch 35/50
# 16/16 - 1s - loss: 14666.7441 - val_loss: 20084.3164 - 635ms/epoch - 40ms/step
# Epoch 36/50
# 16/16 - 1s - loss: 14533.4160 - val_loss: 20415.7461 - 625ms/epoch - 39ms/step
# Epoch 37/50
# 16/16 - 1s - loss: 14375.6162 - val_loss: 19878.2461 - 643ms/epoch - 40ms/step
# Epoch 38/50
# 16/16 - 1s - loss: 14384.8125 - val_loss: 19947.4902 - 629ms/epoch - 39ms/step
# Epoch 39/50
# 16/16 - 1s - loss: 14305.0859 - val_loss: 20337.8574 - 642ms/epoch - 40ms/step
# Epoch 40/50
# 16/16 - 1s - loss: 14153.9873 - val_loss: 20039.2148 - 638ms/epoch - 40ms/step
# Epoch 41/50
# 16/16 - 1s - loss: 13945.6963 - val_loss: 19632.3828 - 657ms/epoch - 41ms/step
# Epoch 42/50
# 16/16 - 1s - loss: 13980.8477 - val_loss: 19665.6660 - 626ms/epoch - 39ms/step
# Epoch 43/50
# 16/16 - 1s - loss: 13991.7012 - val_loss: 20201.3770 - 642ms/epoch - 40ms/step
# Epoch 44/50
# 16/16 - 1s - loss: 13766.0371 - val_loss: 19394.5332 - 729ms/epoch - 46ms/step
# Epoch 45/50
# 16/16 - 1s - loss: 13736.1191 - val_loss: 20892.0059 - 773ms/epoch - 48ms/step
# Epoch 46/50
# 16/16 - 1s - loss: 13835.5986 - val_loss: 19086.9609 - 689ms/epoch - 43ms/step
# Epoch 47/50
# 16/16 - 1s - loss: 13380.6221 - val_loss: 19309.1484 - 631ms/epoch - 39ms/step
# Epoch 48/50
# 16/16 - 1s - loss: 13154.7988 - val_loss: 19043.3887 - 664ms/epoch - 42ms/step
# Epoch 49/50
# 16/16 - 1s - loss: 13199.3066 - val_loss: 19094.5781 - 647ms/epoch - 40ms/step
# Epoch 50/50
# 16/16 - 1s - loss: 13256.1934 - val_loss: 19503.0352 - 642ms/epoch - 40ms/step
#
# Training rmse:  115.13554342328436
# Validation rmse:  139.65326761751763
# 8/8 [==============================] - 0s 6ms/step
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Test accuracy:  130.6385455962038
#
# Training iteration:  4
#
# Epoch 1/50
# 16/16 - 5s - loss: 161618.8906 - val_loss: 156271.2344 - 5s/epoch - 343ms/step
# Epoch 2/50
# 16/16 - 1s - loss: 128559.2031 - val_loss: 72664.3438 - 626ms/epoch - 39ms/step
# Epoch 3/50
# 16/16 - 1s - loss: 66266.5938 - val_loss: 59425.1914 - 629ms/epoch - 39ms/step
# Epoch 4/50
# 16/16 - 1s - loss: 56999.3516 - val_loss: 50006.0625 - 624ms/epoch - 39ms/step
# Epoch 5/50
# 16/16 - 1s - loss: 49300.0195 - val_loss: 46037.7734 - 639ms/epoch - 40ms/step
# Epoch 6/50
# 16/16 - 1s - loss: 43967.3594 - val_loss: 43756.0859 - 630ms/epoch - 39ms/step
# Epoch 7/50
# 16/16 - 1s - loss: 41415.1641 - val_loss: 43676.0078 - 633ms/epoch - 40ms/step
# Epoch 8/50
# 16/16 - 1s - loss: 40218.8164 - val_loss: 43923.9102 - 639ms/epoch - 40ms/step
# Epoch 9/50
# 16/16 - 1s - loss: 39691.8281 - val_loss: 43890.5859 - 638ms/epoch - 40ms/step
# Epoch 10/50
# 16/16 - 1s - loss: 39087.6172 - val_loss: 43028.0000 - 641ms/epoch - 40ms/step
# Epoch 11/50
# 16/16 - 1s - loss: 38486.9922 - val_loss: 42495.2539 - 674ms/epoch - 42ms/step
# Epoch 12/50
# 16/16 - 1s - loss: 37504.7930 - val_loss: 41925.1797 - 735ms/epoch - 46ms/step
# Epoch 13/50
# 16/16 - 1s - loss: 35750.9961 - val_loss: 38968.4609 - 739ms/epoch - 46ms/step
# Epoch 14/50
# 16/16 - 1s - loss: 31287.9766 - val_loss: 31660.1152 - 797ms/epoch - 50ms/step
# Epoch 15/50
# 16/16 - 1s - loss: 25216.6875 - val_loss: 35358.0117 - 664ms/epoch - 42ms/step
# Epoch 16/50
# 16/16 - 1s - loss: 23350.8359 - val_loss: 28661.6895 - 641ms/epoch - 40ms/step
# Epoch 17/50
# 16/16 - 1s - loss: 20451.9453 - val_loss: 27642.7070 - 645ms/epoch - 40ms/step
# Epoch 18/50
# 16/16 - 1s - loss: 19980.5645 - val_loss: 26718.3516 - 630ms/epoch - 39ms/step
# Epoch 19/50
# 16/16 - 1s - loss: 18808.1855 - val_loss: 27478.3984 - 643ms/epoch - 40ms/step
# Epoch 20/50
# 16/16 - 1s - loss: 18928.1699 - val_loss: 24558.0254 - 658ms/epoch - 41ms/step
# Epoch 21/50
# 16/16 - 1s - loss: 18832.9980 - val_loss: 25165.5137 - 631ms/epoch - 39ms/step
# Epoch 22/50
# 16/16 - 1s - loss: 18151.2461 - val_loss: 24090.4785 - 633ms/epoch - 40ms/step
# Epoch 23/50
# 16/16 - 1s - loss: 17513.7148 - val_loss: 23810.0215 - 630ms/epoch - 39ms/step
# Epoch 24/50
# 16/16 - 1s - loss: 16786.6602 - val_loss: 23470.3828 - 642ms/epoch - 40ms/step
# Epoch 25/50
# 16/16 - 1s - loss: 16540.6797 - val_loss: 23272.5605 - 615ms/epoch - 38ms/step
# Epoch 26/50
# 16/16 - 1s - loss: 16400.5371 - val_loss: 21834.7070 - 626ms/epoch - 39ms/step
# Epoch 27/50
# 16/16 - 1s - loss: 16382.9385 - val_loss: 21817.0391 - 653ms/epoch - 41ms/step
# Epoch 28/50
# 16/16 - 1s - loss: 16075.5938 - val_loss: 21287.6641 - 639ms/epoch - 40ms/step
# Epoch 29/50
# 16/16 - 1s - loss: 16162.4580 - val_loss: 22419.5312 - 617ms/epoch - 39ms/step
# Epoch 30/50
# 16/16 - 1s - loss: 16168.4170 - val_loss: 21786.3691 - 699ms/epoch - 44ms/step
# Epoch 31/50
# 16/16 - 1s - loss: 15464.9639 - val_loss: 21859.9902 - 780ms/epoch - 49ms/step
# Epoch 32/50
# 16/16 - 1s - loss: 15253.2393 - val_loss: 21228.8359 - 783ms/epoch - 49ms/step
# Epoch 33/50
# 16/16 - 1s - loss: 15348.9756 - val_loss: 21661.5430 - 677ms/epoch - 42ms/step
# Epoch 34/50
# 16/16 - 1s - loss: 15191.9570 - val_loss: 21523.9863 - 658ms/epoch - 41ms/step
# Epoch 35/50
# 16/16 - 1s - loss: 15144.0205 - val_loss: 20889.8184 - 654ms/epoch - 41ms/step
# Epoch 36/50
# 16/16 - 1s - loss: 14773.7900 - val_loss: 22053.1953 - 631ms/epoch - 39ms/step
# Epoch 37/50
# 16/16 - 1s - loss: 15159.7256 - val_loss: 21931.1426 - 632ms/epoch - 40ms/step
# Epoch 38/50
# 16/16 - 1s - loss: 15112.7275 - val_loss: 20875.6289 - 631ms/epoch - 39ms/step
# Epoch 39/50
# 16/16 - 1s - loss: 14589.4951 - val_loss: 20699.7637 - 648ms/epoch - 41ms/step
# Epoch 40/50
# 16/16 - 1s - loss: 14453.6895 - val_loss: 20275.5371 - 641ms/epoch - 40ms/step
# Epoch 41/50
# 16/16 - 1s - loss: 13956.3711 - val_loss: 21646.3594 - 643ms/epoch - 40ms/step
# Epoch 42/50
# 16/16 - 1s - loss: 14049.3613 - val_loss: 20305.6797 - 671ms/epoch - 42ms/step
# Epoch 43/50
# 16/16 - 1s - loss: 14021.3643 - val_loss: 21959.8203 - 680ms/epoch - 43ms/step
# Epoch 44/50
# 16/16 - 1s - loss: 14235.6914 - val_loss: 19991.0625 - 636ms/epoch - 40ms/step
# Epoch 45/50
# 16/16 - 1s - loss: 13703.5371 - val_loss: 20578.7734 - 627ms/epoch - 39ms/step
# Epoch 46/50
# 16/16 - 1s - loss: 13906.4600 - val_loss: 19758.4219 - 643ms/epoch - 40ms/step
# Epoch 47/50
# 16/16 - 1s - loss: 13512.7549 - val_loss: 19713.1074 - 653ms/epoch - 41ms/step
# Epoch 48/50
# 16/16 - 1s - loss: 13376.6865 - val_loss: 21058.0898 - 672ms/epoch - 42ms/step
# Epoch 49/50
# 16/16 - 1s - loss: 13605.4854 - val_loss: 19620.6094 - 763ms/epoch - 48ms/step
# Epoch 50/50
# 16/16 - 1s - loss: 13322.7295 - val_loss: 19967.6270 - 703ms/epoch - 44ms/step
#
# Training rmse:  115.4241287261355
# Validation rmse:  141.30685387880163
# 8/8 [==============================] - 0s 5ms/step
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Test accuracy:  133.42808810523923
#
# Training iteration:  5
#
# Epoch 1/50
# 16/16 - 5s - loss: 161475.3750 - val_loss: 156315.7344 - 5s/epoch - 294ms/step
# Epoch 2/50
# 16/16 - 1s - loss: 128411.6484 - val_loss: 73712.6641 - 621ms/epoch - 39ms/step
# Epoch 3/50
# 16/16 - 1s - loss: 65691.6953 - val_loss: 58481.5742 - 640ms/epoch - 40ms/step
# Epoch 4/50
# 16/16 - 1s - loss: 56859.7266 - val_loss: 50016.0430 - 621ms/epoch - 39ms/step
# Epoch 5/50
# 16/16 - 1s - loss: 49228.6641 - val_loss: 45784.2656 - 622ms/epoch - 39ms/step
# Epoch 6/50
# 16/16 - 1s - loss: 43832.2383 - val_loss: 43808.7305 - 620ms/epoch - 39ms/step
# Epoch 7/50
# 16/16 - 1s - loss: 41212.4297 - val_loss: 43765.2812 - 631ms/epoch - 39ms/step
# Epoch 8/50
# 16/16 - 1s - loss: 40054.5312 - val_loss: 43852.6914 - 764ms/epoch - 48ms/step
# Epoch 9/50
# 16/16 - 1s - loss: 39519.9727 - val_loss: 43514.6562 - 796ms/epoch - 50ms/step
# Epoch 10/50
# 16/16 - 1s - loss: 38899.5156 - val_loss: 42975.6523 - 772ms/epoch - 48ms/step
# Epoch 11/50
# 16/16 - 1s - loss: 38016.7461 - val_loss: 41880.2812 - 649ms/epoch - 41ms/step
# Epoch 12/50
# 16/16 - 1s - loss: 36233.7500 - val_loss: 39793.4922 - 641ms/epoch - 40ms/step
# Epoch 13/50
# 16/16 - 1s - loss: 32279.0293 - val_loss: 33618.3086 - 645ms/epoch - 40ms/step
# Epoch 14/50
# 16/16 - 1s - loss: 26607.4277 - val_loss: 29600.9727 - 629ms/epoch - 39ms/step
# Epoch 15/50
# 16/16 - 1s - loss: 22726.5957 - val_loss: 30158.3066 - 624ms/epoch - 39ms/step
# Epoch 16/50
# 16/16 - 1s - loss: 21755.3242 - val_loss: 29813.2539 - 617ms/epoch - 39ms/step
# Epoch 17/50
# 16/16 - 1s - loss: 22016.0898 - val_loss: 27548.0801 - 636ms/epoch - 40ms/step
# Epoch 18/50
# 16/16 - 1s - loss: 21310.6758 - val_loss: 27614.7422 - 638ms/epoch - 40ms/step
# Epoch 19/50
# 16/16 - 1s - loss: 21146.7090 - val_loss: 28551.1738 - 621ms/epoch - 39ms/step
# Epoch 20/50
# 16/16 - 1s - loss: 20034.0547 - val_loss: 25885.7090 - 655ms/epoch - 41ms/step
# Epoch 21/50
# 16/16 - 1s - loss: 19623.9355 - val_loss: 26763.5547 - 624ms/epoch - 39ms/step
# Epoch 22/50
# 16/16 - 1s - loss: 19044.8730 - val_loss: 25418.5605 - 627ms/epoch - 39ms/step
# Epoch 23/50
# 16/16 - 1s - loss: 18752.4531 - val_loss: 24775.5469 - 643ms/epoch - 40ms/step
# Epoch 24/50
# 16/16 - 1s - loss: 18116.4219 - val_loss: 24198.7949 - 627ms/epoch - 39ms/step
# Epoch 25/50
# 16/16 - 1s - loss: 17717.8770 - val_loss: 24368.2402 - 624ms/epoch - 39ms/step
# Epoch 26/50
# 16/16 - 1s - loss: 17379.5391 - val_loss: 23698.2793 - 665ms/epoch - 42ms/step
# Epoch 27/50
# 16/16 - 1s - loss: 17413.9102 - val_loss: 24274.4395 - 682ms/epoch - 43ms/step
# Epoch 28/50
# 16/16 - 1s - loss: 17741.9648 - val_loss: 23376.2441 - 770ms/epoch - 48ms/step
# Epoch 29/50
# 16/16 - 1s - loss: 17470.5508 - val_loss: 25674.1953 - 748ms/epoch - 47ms/step
# Epoch 30/50
# 16/16 - 1s - loss: 17332.8008 - val_loss: 22912.0664 - 642ms/epoch - 40ms/step
# Epoch 31/50
# 16/16 - 1s - loss: 15989.2354 - val_loss: 25484.3125 - 634ms/epoch - 40ms/step
# Epoch 32/50
# 16/16 - 1s - loss: 16571.5137 - val_loss: 23387.4785 - 632ms/epoch - 39ms/step
# Epoch 33/50
# 16/16 - 1s - loss: 16294.4443 - val_loss: 22061.6719 - 651ms/epoch - 41ms/step
# Epoch 34/50
# 16/16 - 1s - loss: 15624.3066 - val_loss: 22413.0059 - 633ms/epoch - 40ms/step
# Epoch 35/50
# 16/16 - 1s - loss: 15400.5918 - val_loss: 22713.1328 - 635ms/epoch - 40ms/step
# Epoch 36/50
# 16/16 - 1s - loss: 15355.8320 - val_loss: 22664.1680 - 627ms/epoch - 39ms/step
# Epoch 37/50
# 16/16 - 1s - loss: 15444.6191 - val_loss: 21050.1816 - 639ms/epoch - 40ms/step
# Epoch 38/50
# 16/16 - 1s - loss: 15083.5859 - val_loss: 22833.0625 - 628ms/epoch - 39ms/step
# Epoch 39/50
# 16/16 - 1s - loss: 15029.4307 - val_loss: 21369.3926 - 640ms/epoch - 40ms/step
# Epoch 40/50
# 16/16 - 1s - loss: 14542.1826 - val_loss: 20805.9727 - 634ms/epoch - 40ms/step
# Epoch 41/50
# 16/16 - 1s - loss: 14652.4053 - val_loss: 21137.9141 - 628ms/epoch - 39ms/step
# Epoch 42/50
# 16/16 - 1s - loss: 14280.1162 - val_loss: 19921.9688 - 643ms/epoch - 40ms/step
# Epoch 43/50
# 16/16 - 1s - loss: 14119.7178 - val_loss: 20453.3613 - 650ms/epoch - 41ms/step
# Epoch 44/50
# 16/16 - 1s - loss: 13900.6270 - val_loss: 20491.5859 - 638ms/epoch - 40ms/step
# Epoch 45/50
# 16/16 - 1s - loss: 14199.8418 - val_loss: 19561.7363 - 747ms/epoch - 47ms/step
# Epoch 46/50
# 16/16 - 1s - loss: 14059.2090 - val_loss: 19119.8105 - 765ms/epoch - 48ms/step
# Epoch 47/50
# 16/16 - 1s - loss: 13481.7861 - val_loss: 19324.6836 - 764ms/epoch - 48ms/step
# Epoch 48/50
# 16/16 - 1s - loss: 13449.2246 - val_loss: 19800.7637 - 648ms/epoch - 40ms/step
# Epoch 49/50
# 16/16 - 1s - loss: 13205.6436 - val_loss: 20021.0059 - 619ms/epoch - 39ms/step
# Epoch 50/50
# 16/16 - 1s - loss: 13044.2510 - val_loss: 19308.6074 - 618ms/epoch - 39ms/step
#
# Training rmse:  114.21143102405512
# Validation rmse:  138.9554152304796
# 8/8 [==============================] - 0s 6ms/step
# Test accuracy:  132.95826198294003
#
# Average test rmse:  131.92478031960246
# Standard deviation of test rmse:  1.393989524528

# %%
# Plot the training and validation loss

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.yscale('log')
plt.show()

# %%
# Plot the RMSE loss

plt.plot(np.sqrt(history.history['loss']), label='RMSE Training loss')
plt.plot(np.sqrt(history.history['val_loss']), label='RMSE Validation loss')
plt.legend()
plt.show()

# %%
# Evaluate the model

from sklearn.metrics import mean_squared_error

y_pred = model_copy.predict([X_images_test, X_data_test])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("RMSE:", rmse)
# Out:
# 8/8 [==============================] - 0s 5ms/step
# RMSE: 132.95826198294003
