# %%
import numpy as np
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#       3 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
for i in range(np.max(y_train)+1):
  count = np.count_nonzero(y_train == i)
  print('Class ',i,' has ',count, ' samples')
# Out:
# Class  0  has  5000  samples
# Class  1  has  5000  samples
# Class  2  has  5000  samples
# Class  3  has  5000  samples
# Class  4  has  5000  samples
# Class  5  has  5000  samples
# Class  6  has  5000  samples
# Class  7  has  5000  samples
# Class  8  has  5000  samples
# Class  9  has  5000  samples

# %%
frogs=np.argwhere(y_train.squeeze()==6)

# %%
# Plot five images per class

for c in range(10):
    class_name=np.argwhere(y_train.squeeze()==c)
    fig, axs = plt.subplots(1,5)
    for i in range(5):
        axs[i].imshow(x_train[class_name[i].squeeze(),:,:,:])
        axs[i].set_title('Class '+str(c))
        axs[i].axis('off')
